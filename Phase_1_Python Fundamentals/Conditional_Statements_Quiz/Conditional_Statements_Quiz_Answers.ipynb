# %% [markdown]
# # Conditional Statements Quiz - 20 Questions (Answers)
#
# **Conditional Statements and Control Flow in Python - Answer Key**
#
# This document contains the correct answers for all 20 questions in the Conditional Statements Quiz.
#
# ---

# %% [markdown]
# ## Answer 1: A) `A`
#
# ## Answer 2: B) `B`
#
# ## Answer 3: B) `At least one condition is False`
#
# ## Answer 4: A) `At least one condition is True`
#
# ## Answer 5: C) `3`
#
# ## Answer 6: B) `True False True`
#
# ## Answer 7: B) `"even"`
#
# ## Answer 8: B) `B`
#
# ## Answer 9: B) `False`
#
# ## Answer 10: B) `B`
#
# ## Answer 11: B) `B`
#
# ## Answer 12: A) `A`
#
# ## Answer 13: A) `A`
#
# ## Answer 14: A) `A`
#
# ## Answer 15: A) `A`
#
# ## Answer 16: A) `A`
#
# ## Answer 17: B) `B`
#
# ## Answer 18: B) `"B"`
#
# ## Answer 19: A) `True`
#
# ## Answer 20: A) `A`
#
# ---
#
# For detailed explanations, please refer to the Explanations files.
