# %% [markdown]
# # Python Basics Quiz - 100 Multiple Choice Questions
#
# This quiz covers all topics from the "Learn the Basics" Python course, suitable for 10th-11th grade students.
#
# **Instructions:**
# - Each question has 5 answer options (A, B, C, D, E)
# - Only one answer is correct
# - Questions are in English with clear examples
# - Questions cover: Basic Syntax, Variables, Data Types, Strings, Conditionals, Loops, Typecasting, Exceptions, Functions, Lists, Tuples, Sets, Dictionaries
#
# ---

# %% [markdown]
# ## Question 1
#
# What symbol is used in Python to create a single-line comment?
#
# A) //
# B) /*
# C) #
# D) --
# E) <!--
#
# **Correct Answer: C**
#
# ---

# %% [markdown]
# ## Question 2
#
# What will be the output of: print(10 // 3)
#
# A) 3.33
# B) 3
# C) 4
# D) 3.0
# E) Error
#
# **Correct Answer: B**
#
# ---

# %% [markdown]
# ## Question 3
#
# Which of the following is a valid variable name in Python?
#
# A) 2variable
# B) my-variable
# C) my_variable
# D) variable!
# E) class
#
# **Correct Answer: C**
#
# ---

# %% [markdown]
# ## Question 4
#
# What does the input() function always return?
#
# A) Integer
# B) Float
# C) String
# D) Boolean
# E) List
#
# **Correct Answer: C**
#
# ---

# %% [markdown]
# ## Question 5
#
# What will print('Hello', 'World', sep='-') output?
#
# A) Hello World
# B) Hello-World
# C) Hello, World
# D) HelloWorld
# E) Error
#
# **Correct Answer: B**
#
# ---

# %% [markdown]
# ## Question 6
#
# Which operator is used for exponentiation in Python?
#
# A) ^
# B) **
# C) ^^
# D) exp()
# E) pow only
#
# **Correct Answer: B**
#
# ---

# %% [markdown]
# ## Question 7
#
# What is the result of: 5 % 2
#
# A) 2.5
# B) 1
# C) 0
# D) 2
# E) Error
#
# **Correct Answer: B**
#
# ---

# %% [markdown]
# ## Question 8
#
# Which statement is used to create a variable in Python?
#
# A) var
# B) create
# C) = (assignment)
# D) declare
# E) def
#
# **Correct Answer: C**
#
# ---

# %% [markdown]
# ## Question 9
#
# What will be the type of result after: result = 10 + 3.5
#
# A) int
# B) float
# C) complex
# D) string
# E) tuple
#
# **Correct Answer: B**
#
# ---

# %% [markdown]
# ## Question 10
#
# What is the output of: print(type(True))
#
# A) <class 'int'>
# B) <class 'bool'>
# C) <class 'str'>
# D) <class 'None'>
# E) Error
#
# **Correct Answer: B**
#
# ---

# %% [markdown]
# ## Question 11
#
# Which of the following data types is mutable in Python?
#
# A) tuple
# B) str
# C) list
# D) int
# E) None of these
#
# **Correct Answer: C**
#
# ---

# %% [markdown]
# ## Question 12
#
# What is the output of: len([1, 2, 3])
#
# A) 3
# B) 4
# C) 2
# D) Error
# E) 1
#
# **Correct Answer: A**
#
# ---

# %% [markdown]
# ## Question 13
#
# Which method is used to add an element to the end of a list?
#
# A) insert()
# B) add()
# C) append()
# D) extend()
# E) push()
#
# **Correct Answer: C**
#
# ---

# %% [markdown]
# ## Question 14
#
# What is the result of: (1, 2, 3)[1]
#
# A) 1
# B) 2
# C) 3
# D) (2)
# E) Error
#
# **Correct Answer: B**
#
# ---

# %% [markdown]
# ## Question 15
#
# Which of the following creates an empty dictionary?
#
# A) {}
# B) []
# C) ()
# D) set()
# E) None
#
# **Correct Answer: A**
#
# ---

# %% [markdown]
# ## Question 16
#
# What is the output of: {1, 2, 2, 3}
#
# A) {1, 2, 2, 3}
# B) {1, 2, 3}
# C) {1, 3}
# D) Error
# E) {2}
#
# **Correct Answer: B**
#
# ---

# %% [markdown]
# ## Question 17
#
# How do you access a value in a dictionary?
#
# A) dict.index(key)
# B) dict[key]
# C) dict.get(key)
# D) Both B and C
# E) dict.find(key)
#
# **Correct Answer: D**
#
# ---

# %% [markdown]
# ## Question 18
#
# What is the result of: bool([])
#
# A) True
# B) False
# C) None
# D) Error
# E) []
#
# **Correct Answer: B**
#
# ---

# %% [markdown]
# ## Question 19
#
# Which data type does not allow duplicate elements?
#
# A) list
# B) tuple
# C) set
# D) dict
# E) string
#
# **Correct Answer: C**
#
# ---

# %% [markdown]
# ## Question 20
#
# What is the output of: [1, 2, 3] + [4, 5]
#
# A) [1, 2, 3, 4, 5]
# B) [5, 7]
# C) Error
# D) [[1, 2, 3], [4, 5]]
# E) [1, 2, 3][4, 5]
#
# **Correct Answer: A**
#
# ---

# %% [markdown]
# ## Question 21
#
# What does list.pop() do?
#
# A) Adds an element
# B) Removes and returns the last element
# C) Returns the first element
# D) Sorts the list
# E) Clears the list
#
# **Correct Answer: B**
#
# ---

# %% [markdown]
# ## Question 22
#
# What is the result of: 'Hello'[1:4]
#
# A) 'H'
# B) 'ell'
# C) 'ello'
# D) 'Hell'
# E) Error
#
# **Correct Answer: B**
#
# ---

# %% [markdown]
# ## Question 23
#
# Which of the following is immutable?
#
# A) list
# B) dict
# C) tuple
# D) set
# E) array
#
# **Correct Answer: C**
#
# ---

# %% [markdown]
# ## Question 24
#
# What is the output of: min([5, 2, 8, 1])
#
# A) 1
# B) 5
# C) 8
# D) Error
# E) [1]
#
# **Correct Answer: A**
#
# ---

# %% [markdown]
# ## Question 25
#
# What is the type of: type(None)
#
# A) <class 'None'>
# B) <class 'NoneType'>
# C) <class 'null'>
# D) <class 'empty'>
# E) Error
#
# **Correct Answer: B**
#
# ---

# %% [markdown]
# ## Question 26
#
# What is the output of: 'Python'.upper()
#
# A) 'python'
# B) 'PYTHON'
# C) 'Python'
# D) Error
# E) 'PYTHOn'
#
# **Correct Answer: B**
#
# ---

# %% [markdown]
# ## Question 27
#
# What does 'hello world'.split() return?
#
# A) 'hello world'
# B) ['hello', 'world']
# C) ['h', 'e', 'l', 'l', 'o']
# D) Error
# E) 'helloworld'
#
# **Correct Answer: B**
#
# ---

# %% [markdown]
# ## Question 28
#
# What is the result of: 'Python'.find('th')
#
# A) 2
# B) 3
# C) 4
# D) -1
# E) Error
#
# **Correct Answer: A**
#
# ---

# %% [markdown]
# ## Question 29
#
# What will '  hello  '.strip() return?
#
# A) '  hello  '
# B) 'hello  '
# C) 'hello'
# D) '  hello'
# E) Error
#
# **Correct Answer: C**
#
# ---

# %% [markdown]
# ## Question 30
#
# What is the output of: len('Python')
#
# A) 5
# B) 6
# C) 7
# D) P
# E) Error
#
# **Correct Answer: B**
#
# ---

# %% [markdown]
# ## Question 31
#
# What does 'Hello'.replace('l', 'L') return?
#
# A) 'HeLLo'
# B) 'Hello'
# C) 'HELLO'
# D) Error
# E) 'HelLo'
#
# **Correct Answer: A**
#
# ---

# %% [markdown]
# ## Question 32
#
# What is the result of: 'python'.capitalize()
#
# A) 'Python'
# B) 'PYTHON'
# C) 'python'
# D) 'PYTHOn'
# E) Error
#
# **Correct Answer: A**
#
# ---

# %% [markdown]
# ## Question 33
#
# What will f'Value: {5+3}' evaluate to?
#
# A) 'Value: {5+3}'
# B) 'Value: 8'
# C) Error
# D) 'Value: 5+3'
# E) 'Value: 53'
#
# **Correct Answer: B**
#
# ---

# %% [markdown]
# ## Question 34
#
# What is the output of: 'Python'[::-1]
#
# A) 'Python'
# B) 'nohtyP'
# C) 'P'
# D) Error
# E) 'n'
#
# **Correct Answer: B**
#
# ---

# %% [markdown]
# ## Question 35
#
# What does '123'.isdigit() return?
#
# A) True
# B) False
# C) '123'
# D) Error
# E) None
#
# **Correct Answer: A**
#
# ---

# %% [markdown]
# ## Question 36
#
# What is the result of: 'Python'[1]
#
# A) 'P'
# B) 'y'
# C) 't'
# D) Error
# E) 'Python'
#
# **Correct Answer: B**
#
# ---

# %% [markdown]
# ## Question 37
#
# What will 'Hello' + 'World' produce?
#
# A) 'HelloWorld'
# B) 'Hello World'
# C) Error
# D) 'Hello' + 'World'
# E) 'Helloworld'
#
# **Correct Answer: A**
#
# ---

# %% [markdown]
# ## Question 38
#
# What is the output of: 'Hello' * 3
#
# A) 'HelloHelloHello'
# B) 'Hello3'
# C) Error
# D) 15
# E) 'HHH'
#
# **Correct Answer: A**
#
# ---

# %% [markdown]
# ## Question 39
#
# What does 'hello world'.title() return?
#
# A) 'Hello World'
# B) 'HELLO WORLD'
# C) 'hello world'
# D) Error
# E) 'Hello world'
#
# **Correct Answer: A**
#
# ---

# %% [markdown]
# ## Question 40
#
# What is the result of: 'python'.islower()
#
# A) True
# B) False
# C) 'python'
# D) None
# E) Error
#
# **Correct Answer: A**
#
# ---

# %% [markdown]
# ## Question 41
#
# What is the output of: True and False
#
# A) True
# B) False
# C) None
# D) Error
# E) True, False
#
# **Correct Answer: B**
#
# ---

# %% [markdown]
# ## Question 42
#
# What will be printed: if 5 > 3: print('Yes')
#
# A) Nothing
# B) 'Yes'
# C) True
# D) Error
# E) 5 > 3
#
# **Correct Answer: B**
#
# ---

# %% [markdown]
# ## Question 43
#
# What is the result of: 10 if 5 > 3 else 20
#
# A) 10
# B) 20
# C) True
# D) Error
# E) None
#
# **Correct Answer: A**
#
# ---

# %% [markdown]
# ## Question 44
#
# What is the output of: not True
#
# A) True
# B) False
# C) None
# D) Error
# E) 0
#
# **Correct Answer: B**
#
# ---

# %% [markdown]
# ## Question 45
#
# What will 'a' in 'python' return?
#
# A) True
# B) False
# C) 'a'
# D) Error
# E) None
#
# **Correct Answer: B**
#
# ---

# %% [markdown]
# ## Question 46
#
# What is the result of: 5 == 5.0
#
# A) True
# B) False
# C) Error
# D) None
# E) 5
#
# **Correct Answer: A**
#
# ---

# %% [markdown]
# ## Question 47
#
# What is the output of: 5 is 5
#
# A) True
# B) False
# C) Error
# D) None
# E) 5
#
# **Correct Answer: A**
#
# ---

# %% [markdown]
# ## Question 48
#
# What will be executed: if 0: print('Yes') else: print('No')
#
# A) 'Yes'
# B) 'No'
# C) Nothing
# D) Error
# E) 0
#
# **Correct Answer: B**
#
# ---

# %% [markdown]
# ## Question 49
#
# What is the result of: True or False
#
# A) True
# B) False
# C) None
# D) Error
# E) True, False
#
# **Correct Answer: A**
#
# ---

# %% [markdown]
# ## Question 50
#
# What is the output of: x = 10; 'Even' if x % 2 == 0 else 'Odd'
#
# A) 'Even'
# B) 'Odd'
# C) 10
# D) Error
# E) None
#
# **Correct Answer: A**
#
# ---

# %% [markdown]
# ## Question 51
#
# What will: if []: print('Yes') else: print('No') print?
#
# A) 'Yes'
# B) 'No'
# C) Nothing
# D) Error
# E) []
#
# **Correct Answer: B**
#
# ---

# %% [markdown]
# ## Question 52
#
# What is the result of: 3 in [1, 2, 3, 4]
#
# A) True
# B) False
# C) 3
# D) Error
# E) None
#
# **Correct Answer: A**
#
# ---

# %% [markdown]
# ## Question 53
#
# What is the output of: 5 != 5
#
# A) True
# B) False
# C) Error
# D) None
# E) 5
#
# **Correct Answer: B**
#
# ---

# %% [markdown]
# ## Question 54
#
# What will: if '': print('Yes') else: print('No') print?
#
# A) 'Yes'
# B) 'No'
# C) ''
# D) Error
# E) Nothing
#
# **Correct Answer: B**
#
# ---

# %% [markdown]
# ## Question 55
#
# What is the result of: 5 > 3 and 10 < 20
#
# A) True
# B) False
# C) Error
# D) None
# E) 5, 10
#
# **Correct Answer: A**
#
# ---

# %% [markdown]
# ## Question 56
#
# What is the output of: not (5 > 10)
#
# A) True
# B) False
# C) 5
# D) Error
# E) None
#
# **Correct Answer: A**
#
# ---

# %% [markdown]
# ## Question 57
#
# What will: score = 85; 'A' if score >= 90 else 'B' if score >= 80 else 'C' return?
#
# A) 'A'
# B) 'B'
# C) 'C'
# D) Error
# E) 85
#
# **Correct Answer: B**
#
# ---

# %% [markdown]
# ## Question 58
#
# What is the result of: 0 or 10
#
# A) 0
# B) 10
# C) True
# D) False
# E) Error
#
# **Correct Answer: B**
#
# ---

# %% [markdown]
# ## Question 59
#
# What is the output of: 5 and 0
#
# A) 5
# B) 0
# C) True
# D) False
# E) Error
#
# **Correct Answer: B**
#
# ---

# %% [markdown]
# ## Question 60
#
# What will: if None: print('Yes') else: print('No') print?
#
# A) 'Yes'
# B) 'No'
# C) None
# D) Error
# E) Nothing
#
# **Correct Answer: B**
#
# ---

# %% [markdown]
# ## Question 61
#
# What is the output of: for i in range(3): print(i)
#
# A) 0 1 2
# B) 1 2 3
# C) 3
# D) Error
# E) range(3)
#
# **Correct Answer: A**
#
# ---

# %% [markdown]
# ## Question 62
#
# What will: for i in 'abc': print(i) print?
#
# A) 'abc'
# B) a b c
# C) 0 1 2
# D) Error
# E) ['a', 'b', 'c']
#
# **Correct Answer: B**
#
# ---

# %% [markdown]
# ## Question 63
#
# What is the result of: list(range(5))
#
# A) [0, 1, 2, 3, 4]
# B) [1, 2, 3, 4, 5]
# C) [5]
# D) Error
# E) range(5)
#
# **Correct Answer: A**
#
# ---

# %% [markdown]
# ## Question 64
#
# What does range(1, 5) generate?
#
# A) [1, 2, 3, 4, 5]
# B) [1, 2, 3, 4]
# C) [0, 1, 2, 3, 4]
# D) Error
# E) [5]
#
# **Correct Answer: B**
#
# ---

# %% [markdown]
# ## Question 65
#
# What is the output of: sum([1, 2, 3, 4])
#
# A) 10
# B) [1, 2, 3, 4]
# C) 4
# D) Error
# E) 24
#
# **Correct Answer: A**
#
# ---

# %% [markdown]
# ## Question 66
#
# What will: for i in range(3): if i == 1: break; print(i) print?
#
# A) 0 1 2
# B) 0 1
# C) 0
# D) 1
# E) Nothing
#
# **Correct Answer: C**
#
# ---

# %% [markdown]
# ## Question 67
#
# What is the result of: [x*2 for x in range(3)]
#
# A) [0, 2, 4]
# B) [2, 4, 6]
# C) [1, 2, 3]
# D) Error
# E) range(6)
#
# **Correct Answer: A**
#
# ---

# %% [markdown]
# ## Question 68
#
# What does: i = 0; while i < 3: print(i); i += 1 output?
#
# A) 0 1 2
# B) 1 2 3
# C) 0 1
# D) Infinite loop
# E) Error
#
# **Correct Answer: A**
#
# ---

# %% [markdown]
# ## Question 69
#
# What is the output of: for i in range(3): if i == 1: continue; print(i)
#
# A) 0 1 2
# B) 0 2
# C) 1
# D) 0 1
# E) Error
#
# **Correct Answer: B**
#
# ---

# %% [markdown]
# ## Question 70
#
# What will: for x, y in enumerate(['a', 'b']): print(x, y) print?
#
# A) 0 a 1 b
# B) a b
# C) (0, 'a') (1, 'b')
# D) Error
# E) ['a', 'b']
#
# **Correct Answer: A**
#
# ---

# %% [markdown]
# ## Question 71
#
# What is the result of: list(range(0, 10, 2))
#
# A) [0, 2, 4, 6, 8]
# B) [2, 4, 6, 8, 10]
# C) [0, 2, 4, 6, 8, 10]
# D) Error
# E) [1, 3, 5, 7, 9]
#
# **Correct Answer: A**
#
# ---

# %% [markdown]
# ## Question 72
#
# What is the output of: [i for i in range(5) if i % 2 == 0]
#
# A) [0, 2, 4]
# B) [1, 3, 5]
# C) [0, 1, 2, 3, 4]
# D) Error
# E) [2, 4]
#
# **Correct Answer: A**
#
# ---

# %% [markdown]
# ## Question 73
#
# What does: for key, value in {'a': 1, 'b': 2}.items(): print(key, value) output?
#
# A) a 1 b 2
# B) ('a', 1) ('b', 2)
# C) ['a', 'b']
# D) Error
# E) 1 2
#
# **Correct Answer: A**
#
# ---

# %% [markdown]
# ## Question 74
#
# What is the result of: max([5, 2, 8, 1])
#
# A) 8
# B) 5
# C) 1
# D) Error
# E) [8]
#
# **Correct Answer: A**
#
# ---

# %% [markdown]
# ## Question 75
#
# What will: for i in range(3): pass; print('Done') print?
#
# A) Nothing
# B) 'Done'
# C) 'Done' three times
# D) Error
# E) 0 1 2 'Done'
#
# **Correct Answer: B**
#
# ---

# %% [markdown]
# ## Question 76
#
# What is the output of: [x+y for x in [1,2] for y in [3,4]]
#
# A) [4, 5, 5, 6]
# B) [4, 5]
# C) [1, 2, 3, 4]
# D) Error
# E) [7, 9]
#
# **Correct Answer: A**
#
# ---

# %% [markdown]
# ## Question 77
#
# What does: result = []; [result.append(i) for i in range(3)]; print(result) output?
#
# A) [0, 1, 2]
# B) [None, None, None]
# C) Error
# D) []
# E) [[0, 1, 2]]
#
# **Correct Answer: A**
#
# ---

# %% [markdown]
# ## Question 78
#
# What is the result of: sorted([3, 1, 2])
#
# A) [1, 2, 3]
# B) [3, 1, 2]
# C) (1, 2, 3)
# D) Error
# E) {1, 2, 3}
#
# **Correct Answer: A**
#
# ---

# %% [markdown]
# ## Question 79
#
# What will: count = 0; while count < 3: count += 1; print(count) output?
#
# A) 0 1 2
# B) 1 2 3
# C) 3
# D) Infinite loop
# E) Error
#
# **Correct Answer: B**
#
# ---

# %% [markdown]
# ## Question 80
#
# What is the output of: any([False, False, True])
#
# A) True
# B) False
# C) [True]
# D) Error
# E) None
#
# **Correct Answer: A**
#
# ---

# %% [markdown]
# ## Question 81
#
# What is the result of: int(3.7)
#
# A) 3
# B) 4
# C) 3.7
# D) Error
# E) 3.0
#
# **Correct Answer: A**
#
# ---

# %% [markdown]
# ## Question 82
#
# What will: str(123) return?
#
# A) 123
# B) '123'
# C) Error
# D) None
# E) [1, 2, 3]
#
# **Correct Answer: B**
#
# ---

# %% [markdown]
# ## Question 83
#
# What is the output of: float('3.14')
#
# A) 3
# B) 3.14
# C) '3.14'
# D) Error
# E) 314
#
# **Correct Answer: B**
#
# ---

# %% [markdown]
# ## Question 84
#
# What does: try: 10/0; except ZeroDivisionError: print('Error') print?
#
# A) 0
# B) 'Error'
# C) Nothing
# D) 10
# E) Traceback
#
# **Correct Answer: B**
#
# ---

# %% [markdown]
# ## Question 85
#
# What is the result of: list('abc')
#
# A) ['a', 'b', 'c']
# B) 'abc'
# C) ['abc']
# D) Error
# E) ('a', 'b', 'c')
#
# **Correct Answer: A**
#
# ---

# %% [markdown]
# ## Question 86
#
# What will: def add(x, y): return x+y; add(3, 4) return?
#
# A) 7
# B) 'x+y'
# C) Error
# D) None
# E) add
#
# **Correct Answer: A**
#
# ---

# %% [markdown]
# ## Question 87
#
# What is the output of: tuple([1, 2, 3])
#
# A) [1, 2, 3]
# B) (1, 2, 3)
# C) {1, 2, 3}
# D) Error
# E) 1, 2, 3
#
# **Correct Answer: B**
#
# ---

# %% [markdown]
# ## Question 88
#
# What does: bool(0) return?
#
# A) True
# B) False
# C) 0
# D) None
# E) Error
#
# **Correct Answer: B**
#
# ---

# %% [markdown]
# ## Question 89
#
# What is the result of: set([1, 2, 2, 3])
#
# A) {1, 2, 2, 3}
# B) {1, 2, 3}
# C) [1, 2, 3]
# D) Error
# E) (1, 2, 3)
#
# **Correct Answer: B**
#
# ---

# %% [markdown]
# ## Question 90
#
# What will: lambda x: x*2 (5) return?
#
# A) 10
# B) 'x*2'
# C) Error
# D) None
# E) lambda
#
# **Correct Answer: A**
#
# ---

# %% [markdown]
# ## Question 91
#
# What is the output of: dict([('a', 1), ('b', 2)])
#
# A) {'a': 1, 'b': 2}
# B) [('a', 1), ('b', 2)]
# C) Error
# D) {'a', 'b'}
# E) (1, 2)
#
# **Correct Answer: A**
#
# ---

# %% [markdown]
# ## Question 92
#
# What does: all([True, True, False]) return?
#
# A) True
# B) False
# C) [True, True, False]
# D) Error
# E) None
#
# **Correct Answer: B**
#
# ---

# %% [markdown]
# ## Question 93
#
# What is the result of: ' '.join(['Hello', 'World'])
#
# A) 'HelloWorld'
# B) 'Hello World'
# C) ['Hello', 'World']
# D) Error
# E) 'Hello,World'
#
# **Correct Answer: B**
#
# ---

# %% [markdown]
# ## Question 94
#
# What will: try: int('abc'); except ValueError as e: type(e).__name__ return?
#
# A) 'ValueError'
# B) 'int'
# C) Error
# D) 'abc'
# E) None
#
# **Correct Answer: A**
#
# ---

# %% [markdown]
# ## Question 95
#
# What is the output of: def f(x=5): return x; f()
#
# A) 5
# B) Error
# C) None
# D) 'x'
# E) f
#
# **Correct Answer: A**
#
# ---

# %% [markdown]
# ## Question 96
#
# What does: list(range(3)) + [3, 4] return?
#
# A) [0, 1, 2, 3, 4]
# B) [3, 3, 4]
# C) Error
# D) [0, 1, 2][3, 4]
# E) 12
#
# **Correct Answer: A**
#
# ---

# %% [markdown]
# ## Question 97
#
# What is the result of: [1, 2, 3].index(2)
#
# A) 1
# B) 2
# C) 0
# D) Error
# E) True
#
# **Correct Answer: A**
#
# ---

# %% [markdown]
# ## Question 98
#
# What will: 'Python'.count('P') return?
#
# A) 1
# B) 0
# C) True
# D) Error
# E) 'P'
#
# **Correct Answer: A**
#
# ---

# %% [markdown]
# ## Question 99
#
# What is the output of: (1, 2) + (3, 4)
#
# A) (1, 2, 3, 4)
# B) (4, 6)
# C) Error
# D) ((1, 2), (3, 4))
# E) 10
#
# **Correct Answer: A**
#
# ---

# %% [markdown]
# ## Question 100
#
# What does: {'a': 1}.get('b', 0) return?
#
# A) 1
# B) 0
# C) 'b'
# D) Error
# E) None
#
# **Correct Answer: B**
#
# ---

# %% [markdown]
# ## Question 101
#
# What is the result of: round(3.14159, 2)
#
# A) 3.14
# B) 3.1
# C) 3
# D) Error
# E) 3.14159
#
# **Correct Answer: A**
#
# ---
